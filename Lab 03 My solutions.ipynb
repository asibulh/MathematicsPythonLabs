# %% [markdown]
# # Lab 3 - My Solutions
# **Piecewise functions**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Asibul Hasan" # Write your name between parenthesis
student_id =2601761 # Change your student ID here
date_returned = "05.04.2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display
import numpy as np
import matplotlib.pyplot as plt
import labx as mx

# %% [markdown]
# ---
# # Problem 1

# %%
# Run the code below to see your problem text
txt = mx.lab_3_problem_1(student_id)
display(Markdown(txt))
# Out:
# In this problem your task is to create and plot a piecwise
# continuous function in range $ x \in [-10, 10] $.
#
# The function is defined as:<br>
#
# $$ f(x)  = \begin{cases}
# 0 & x < 0.5  \\
# -0.5 + x & 0.5 \leq x < 3.5 \\
# 6.5 - x & 3.5 \leq x < 6.5 \\
# 0 & x \geq 6.5
# \end{cases} $$
#
# Draw the function within the given range of x.
#
# Remember to decorate the plots with title, axis labels, and a legend. Add also grid
# lines to the plots to make them easier to read.

# %% [markdown]
# ### My solution

# %%
# start your code here
#x values
x = np.linspace(-10, 10, 2000)

# piecewise function
y = (
((x>= 0.5) & (x< 3.5)) * (-0.5 + x) +
((x>= 3.5) & (x< 6.5)) * (6.5- x)
)
#plot
plt.figure(figsize=(7,4))
plt.plot(x, y, label="Triangle Function")
plt.title(f"Smooth Triangle Piecewise Function for student {student_id}")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## Problem 2

# %%
# Run the code below to see your problem text
txt = mx.lab_3_problem_2(student_id)
display(Markdown(txt))
# Out:
# In this problem your task is to create and plot a piecwise
# continuous function in range $ x \in [-10, 10] $.
#
# The function is defined as:<br>
#
# $$ f(x)  = \begin{cases}
# -154.79 & x < -7.8  \\
# 0.1x^3 + -1.16x^2 + 4.15x + -4.39 & -7.8 \leq x < 7.6 \\
# 4.05 & x \geq 7.6
# \end{cases} $$
#
# Draw the function within the given range of x.
#
# Remember to decorate the plots with title, axis labels, and a legend. Add also grid
# lines to the plots to make them easier to read.

# %% [markdown]
# ### My solution

# %%
# Your code starts here
#x values
x = np.linspace(-10, 10, 2000)

# Piecewise function using boolean arrays
y= (
(x < -7.8) * (-154.79) +
((x >= -7.8) & (x < 7.6)) *
(0.1*x**3 - 1.16*x**2 + 4.15*x - 4.39) +
(x >=7.6) * (4.05)
)

#plot
plt.figure(figsize=(10,6))
plt.plot(x, y, label="Piecewise Continuous Function", color="blue")

plt.title(f"Smooth Continuous Piecewise Function for student {student_id}")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()
