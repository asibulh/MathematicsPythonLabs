# %%
import numpy as np
import plt

x = np.arange (0,5,0.05)
y = np.sin(x*np.pi)

plt.figure(figsize=(3,2))
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import plt

x = np.arange (1,5,0.1)
y = np.sin(x*np.pi)

plt.figure(figsize=(3,2))
plt.plot(x,y)
plt.show()
