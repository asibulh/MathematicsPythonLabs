# %%
from IPython.display import Markdown, display # IPython.display is used to display Markdown text in Jupyter notebooks
import numpy as np # numpy is used for numerical calculations
import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
import labx as mx # Remember to download labx module from OMA assignment !!!
# Out:
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:77: SyntaxWarning: invalid escape sequence '\i'
#   return txt
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:75: SyntaxWarning: invalid escape sequence '\l'
#   Add also grid lines to the plots to make them easier to read."""
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:75: SyntaxWarning: invalid escape sequence '\l'
#   Add also grid lines to the plots to make them easier to read."""
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:107: SyntaxWarning: invalid escape sequence '\i'
#   return txt
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:77: SyntaxWarning: invalid escape sequence '\i'
#   return txt
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:75: SyntaxWarning: invalid escape sequence '\l'
#   Add also grid lines to the plots to make them easier to read."""
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:75: SyntaxWarning: invalid escape sequence '\l'
#   Add also grid lines to the plots to make them easier to read."""
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:107: SyntaxWarning: invalid escape sequence '\i'
#   return txt
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np # numpy is used for numerical calculations
#       3 import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
# ----> 4 import labx as mx # Remember to download labx module from OMA assignment !!!
#
# File ~\PycharmProjects\MathematicsPythonLabs\labx.py:4
#       1 # Write a Python function that takes an integer as input
#       2 # and returns a second order polynomial function using
#       3 # the input integer as a seed for a numpy random number generator.
# ----> 4 import Remember
#       5 import numpy as np
#       6 import time
#
# ModuleNotFoundError: No module named 'Remember'

# %%
# Graph overview
#from the graph we observe where the function f(x) intersects the horizontal line y= 1
#the graph shows that the function crosses the line y=1 at two points:
      #one intersection on the negative side of the x-axis
      #one intersection on the positive side of the x-axis


plt.figure(figsize=(7,5))
plt.plot(x, y)

plt.xlim(-7.5, -6.5)                            # zoom area
plt.ylim(0, 2)

plt.axhline(y=1, color='r', linestyle='--')     # y = 1 line

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Intersection Point 1 (Zoomed)")
plt.grid(True)
plt.show()



plt.figure(figsize=(7,5))
plt.plot(x, y)

plt.xlim(2.5, 3.5)     # zoom area
plt.ylim(0, 2)

plt.axhline(y=1, color='r', linestyle='--')       # y = 1 line
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Intersection Point 2 (Zoomed)")
plt.grid(True)
plt.show()

#For example: x₁ ≈ -6.72   x₂ ≈ 3.14
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       1 # Graph overview
#       2 #from the graph we observe where the function f(x) intersects the horizontal line y= 1
#       3 #the graph shows that the function crosses the line y=1 at two points:
#       4       #one intersection on the negative side of the x-axis
#       5       #one intersection on the positive side of the x-axis
# ----> 8 plt.figure(figsize=(7,5))
#       9 plt.plot(x, y)
#      11 plt.xlim(-7.5, -6.5)                            # zoom area
#
# NameError: name 'plt' is not defined
