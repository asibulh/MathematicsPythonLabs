# %% [markdown]
# # Lab 1 - My solutions
# **Basics of numpy and matplotlib**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
from operator import gt

name = "Asibul Hasan" # Write your name between the parenthesis
student_id = 2601761 # Change your student ID here
date_returned = "20.03.2026" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display
import numpy as np
import matplotlib.pyplot as plt
import labx as mx
# Out:
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:76: SyntaxWarning: invalid escape sequence '\i'
#   return txt
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:74: SyntaxWarning: invalid escape sequence '\l'
#   lines to the plots to make them easier to read."""
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:74: SyntaxWarning: invalid escape sequence '\l'
#   lines to the plots to make them easier to read."""
# C:\Users\user\PycharmProjects\MathematicsPythonLabs\labx.py:106: SyntaxWarning: invalid escape sequence '\i'
#   return txt

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
# Problem 1 - Drawing the function

#1 Create the x array
x = np.arange(-10, 10, 0.001)

#2  Calculate the y value
y = mx.lab_1_problem_1(x, student_id)

# Graph plot
plt.figure(figsize = (8, 5))
plt.plot(x, y)

# Graph decorate
plt.title(f"Function f(x) for student {student_id}")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## My solution for problem 2

# %%
# Graph overview
#from the graph we observe where the function f(x) intersects the horizontal line y= 1
#the graph shows that the function crosses the line y=1 at two points:
      #one intersection on the negative side of the x-axis
      #one intersection on the positive side of the x-axis


plt.figure(figsize=(7, 5))
plt.plot(x, y)

plt.xlim(-5.5, -4.0)      # zoom area
plt.ylim(0, 2)

plt.axhline(y=1, color='r', linestyle='--')     # y = 1 line

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Point 1 - Zoomed view')
plt.grid(True)
plt.show()

#Observation [x₁ = approximately -4.80]



plt.figure(figsize=(7, 5))
plt.plot(x, y)

plt.xlim(0.5, 2.0)    # zoom area
plt.ylim(0, 2)

plt.axhline(y=1, color='r', linestyle='--')     # y = 1 line

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Point 2 - Zoomed view')
plt.grid(True)
plt.show()

#Observation [x₂ = approximately  1.20]
